# %% [markdown]
# <img src="img/tuc_logo.png">
#
# # <center> Πολυτεχνείο Κρήτης </center>
#
# ## <center> Γεωγραφικά Συστήματα Πληροφοριών </center>
#
# ### Διδάσκων: Παναγιώτης Παρτσινέβελος, Αν. Καθηγητής
# ### Εργαστήριο: Γεώργιος Πετράκης, Υπ. Διδάκτωρ

# %% [markdown]
# ### Όνομα / Επίθετο:

# %% [markdown]
# # Σειρά Ασκήσεων Python

# %% [markdown]
# 1) Γράψτε ένα πρόγραμμα Python το οποίο να δέχεται από το πληκτρολόγιο τις καρτεσιανές συντεταγμένες τεσσάρων σημείων `Α(x1, y1)` και `Β(x2, y2)`, `Γ(x3, y3)`, και `Δ(x4, y4)` και να υπολογίζει τα μήκη των ευθυγραμμων τμημάτων ΑΒ και ΓΔ με χρήση του τύπου: <br><br> dist = $\sqrt{(x_2 - x_1)^2 + (y_2 - y_1)^2}$
# <br> Στη συνέχεια να εμφανίζει στην οθόνη το μεγαλύτερο ευθύγραμο τμήμα από τα δύο ενώ αν είναι ίσα να εμφανίζει ένα αντίστοιχο μήνυμα.

# %%
# Your code here...

# %% [markdown]
# 2) Γράψτε ένα πρόγραμμα Python το οποίο να δέχεται από το πληκτρολόγιο ένα σημείο (Χ, Υ) ως είσοδο. Οι συντεταγμένες θα πρέπει να είναι μόνο θετικοί αριθμοί ενώ αν ο χρήστης εισάγει αρνητικούς αριθμούς το πρόγραμμα θα ζητάει ξανά από το χρήστη να εισάγει δύο θετικούς αριθμούς. Αν ο χρήστης για τρεις συνεχόμενες φορές εισάγει έστω και έναν αρνητικό αριθμό, το σύστημα θα τερματίζεται χωρίς να εξάγει κάποιο αποτέλεσμα. Αν σε μία από τις προσπάθειες ο χρήστης εισάγει δύο θετικούς αριθμούς για X και Y αντίστοιχα τότε θα εμφανίζει το μήνυμα: "Thank you"

# %%
# Your code here...

# %% [markdown]
# 3) Δημιουργήστε μια συνάρτηση (function) που να ονομάζεται `create_point()` και θα δέχεται δύο παραμέτρους (x, y). Η συνάρτηση θα δημιουργεί ένα Point αντικείμενο και θα το επιστρέφει. Τέλος καλέστε την συνάρτηση που δημιουργήσατε και με την συνάρτηση `print()` εμφανίστε ως αντικείμενα τα σημεία (1.3, 3.3), (5, 2) και (5.1, 8.7). Αν έχετε κάνει σωστά τη διαδικασία θα πρέπει να εμφανιστεί το output: POINT (Χ Υ) για κάθε σημείο όπου Χ και Υ οι συντεταγμένες του κάθε σημείου.

# %%
# Your code here...

# %% [markdown]
# 4) Δημιουγήστε μια συνάρτηση που να ονομάζεται `create_line()` η οποία να δέχεται ως παράμετρο μία λίστα από σημεία της μορφής: `(x, y)`, και να επιστρέφει ένα LineString αντικείμενο από τα σημεία που εισήχθησαν σαν input. Τέλος καλέστε την συνάρτηση που δημιουργήσατε και με την συνάρτηση `print()` εμφανίστε ως αντικείμενα τρία Linestrings. Αν έχετε κάνει σωστά τη διαδικασία θα πρέπει να εμφανιστεί το output: LINESTRING(x1 y1, x2 y2, x3 y3, ...) για κάθε ένα από τα τρία LineStrings.

# %%
# Your code here...

# %% [markdown]
# 5) Δημιουργήστε μία συνάρτηση που να ονομάζεται `create_poly` όπου θα δέχεται μία παράμετρο με το όνομα `coords`. H παράμετρος αυτή θα περιέχει μία λίστα από τουλάχιστον 3 tuples. Τέλος καλέστε την συνάρτηση που δημιουργήσατε και με την συνάρτηση `print()` εμφανίστε ως αντικείμενα τρία Polygons. Αν έχετε κάνει σωστά τη διαδικασία θα πρέπει να εμφανιστεί το output: POLYGON (x1 y1, x2 y2, x3 y3, ...) για κάθε ένα από τα τρία Polygons.

# %%
# Your code here...

# %% [markdown]
# 6) Δημιουργήστε μία κλάση η οποία να δημιουργεί ένα Polygon αντικείμενο ενώ με τις μεθόδους `get_area()` και `get_centroid()` που θα περιλαμβάνει, θα υπολογίζει την επιφάνεια του και το κέντρο βάρους του (centroid) αντίστοιχα. Αποδείξτε την λειτουργία της, δημιουργώντας το αντικείμενο `myPolygon` και υπολογίστε την επιφάνεια και το κέντρο βάρους του μέσω της κλάσης που φτιάξατε. Προσοχή: Μη χρησιμοποιήσετε τις συναρτήσεις που φτιάξατε στις προηγούμενες ασκήσεις. Δουλέψτε αποκλειστικά με τη βιβλιοθήκη Shapely.

# %%
# Your code here...

# %% [markdown]
# 7 α) Γράψτε ένα πρόγραμμα το οποίο να διαβάζει το αρχείο oikismoi2000 (το οποίο θα κατεβάσετε από το e-class του μαθήματος), και θα υπολογίζει τα εμβαδά των τελευταίων 5 οντοτήτων του αρχείου ενώ θα εμφανίζει στην οθόνη το σύστημα αναφοράς του (EPSG). Στη συνέχεια δημιουργήστε ένα αντίγραφο του αρχείου χρησιμοποιώντας την συνάρτηση `copy()` που θα λειτουργεί σαν backup και μετασχηματίστε το σύστημα αναφοράς του αρχείου που έχει φορτωθεί στη μνήμη, στο σύστημα WGS84. Στη συνέχεια γράψτε το αποτέλεσμα στο δίσκο δημιουργώντας ένα νέο shapefile με το όνομα `oikismoi2000_wgs84.shp`. <br>
# β) Γράψτε μία for loop που να ελέγχει αν τo σημείo (509699, 3929906) βρίσκεται εντός κάποιου από τους 1252 οικισμούς που βρίσκονται στο αρχικό σας αρχείο και εμφανίστε τις συντεταγμένες του αντίστοιχου πολυγώνου.

# %%
# Your code here...

# %% [markdown]
# # Απαραίτητες οδηγίες για την επίλυση και υποβολή των ασκήσεων
# Κάτω απο κάθε εκφώνηση βρίσκεται ένα πεδίο (cell) (# your code here...) που θα γράψετε τον κώδικα σας ώστε να επιλυθεί η άσκηση. Για να εκτελεστεί ο κώδικας σε κάθε cell θα πρέπει να επιλέγετε shift-enter. Τα αποτελέσματα ή τα σφάλματα που θα εξάγονται, θα εμφανίζονται ακριβώς από κάτω. <br>
#
# Πριν την υποβολή επιλέξτε με το ποντίκι το όνομα του αρχείου: Exercises_Python_all_final που βρίσκεται πάνω αριστερά της οθόνης και μετονομάστε το σε: Ex_python_epitheto_onoma
#
# Επίσης στο κενό cell που υπάρχει κάτω από το "Ονομα / Επίθετο", πληκτρολογείστε το όνομα και το επίθετο σας. Στη συνέχεια επιλέξτε shift-enter.
#
# Η υποβολή της άσκησης θα γίνεται αποδεκτή ΜΟΝΟ μέσω του e-class. Κατά την υποβολή της σειράς ασκήσεων Python θα παραδώσετε ΜΟΝΟ το αρχείο .ipynb που περιέχει τις εκφωνήσεις με συμπληρωμένο τον κώδικα που γράψατε για κάθε άσκηση.
#
# Η προθεσμία υποβολής της σειράς ασκήσεων Python είναι την Τετάρτη 17 / 11 / 2021 και ώρα 00:00 το βράδυ.
