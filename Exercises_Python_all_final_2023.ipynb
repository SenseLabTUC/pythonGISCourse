# %% [markdown]
# <img src="img/tuc_logo.png">
#
# # <center> Πολυτεχνείο Κρήτης </center>
#
# ## <center> Γεωγραφικά Συστήματα Πληροφοριών </center>
#
# ### Διδάσκων: Παναγιώτης Παρτσινέβελος
# ### Εργαστήριο:  Γεώργιος Πετράκης - Nίκος Σπανουδάκης

# %% [markdown]
# ### Όνομα / Επίθετο:

# %% [markdown]
# # Σειρά Ασκήσεων Python

# %% [markdown]
# 1) Να γραφτεί ένα πρόγραμμα Η/Υ το οποίο να υπολογίζει το εμβαδόν δύο παραλληλογράμμων και στη συνέχεια να εκτυπώνει το μεγαλύτερο. Πιο συγκεκριμένα, ο χρήστης (δηλαδή εσείς) θα πρέπει να εισάγει το μήκος της βάσης και το ύψος για κάθε παραλληλόγραμμο, ενώ στην συνέχεια το πρόγραμμα θα πρέπει να υπολογίζει τα δύο εμβαδά και να εκτυπώνει το μεγαλύτερο.

# %%
# code

# %% [markdown]
# 2. Να γράψετε ένα πρόγραμμα Η/Υ όπου ο χρήστης να εισάγει τις τρεις πλευρές ενός τριγώνου και το πρόγρμμα να εξάγει αν το τρίγωνο που προκύπτει είναι ορθογώνιο, αμβλυγώνιο ή οξυγώνιο και ισοσκελές, σκαλινό ή ισόπλευρο. Προσοχή: η βιβλιοθήκη math που θα χρησιμοποιήστε υπολογίζει τις τριγωνομετρικές συναρτήσεις (πχ tan(), cos(), κλπ) σε rad, επομένως θα χρειαστεί να μετατρέψετε το αποτέλεσμα σε μοίρες.

# %%
# code

# %% [markdown]
# 3) Έστω ότι βρίσκεστε στο σημείο Α(501367.1, 3929888.4) ενώ κοντά σας υπάρχουν τέσσερα καφέ στα σημεία Κ1(501388.3, 3929933.8), Κ2(501290.2, 3929958.0), Κ3(501352.2, 3929907.8), Κ4(501339.9, 3930046.3). Γράψτε ένα πρόγραμμα το οποίο να βρίσκει το καφέ που είναι πιο κοντά σε εσάς. Προσοχή ! Δεν μας ενδιαφέρει πόση είναι η απόσταση, αλλά ποιο καφέ είναι πιο κοντά. Για να λύσετε την άσκηση χρησιμοποιείστε την βιβλιοθήκη "shapely".

# %%
# code

# %% [markdown]
# 4) Χρησιμοποιώντας τα δεδομένα της άσκησης 2, γράψτε ένα πρόγραμμα που να εξάγει ποια καφέ από τα παραπάνω βρίσκονται σε ακτίνα 60 μέτρων από την θέση σας (δηλαδή το σημείο Α).

# %%
# code

# %% [markdown]
# 5) Έστω δύο περιοχές Α [(491555,3921979), (491817, 3921317), (491183, 3921000), (490760, 3921734)] και Β [(491216, 3921957), (491277, 3921667), (491544, 3921273), (492045, 3921122), (492673, 3921501), (492523, 3922313), (491516, 3922535)].
# Φτιάξτε ένα πρόγραμμα όπου υπολογίζει:
# α) Αν οι δύο περιοχές επικαλύπτονται εξάγοντας το μήνημα: "Οι περιοχές επικαλύπτονται" ή "Οι περιοχές δεν επικαλύπτονται" ανάλογα με το αποτέλεσμα.
# β) Αν υποθέσουμε ότι ένας άνθρωπος βρίσκεται στην θέση: Γ(491377, 3921784) βρείτε αν ο άνθρωπος αυτός βρίσκεται εντός ή εκτός της τομής των δύο περιοχών (εφόσον αυτές επικαλύπτονται).

# %%
# code

# %% [markdown]
# 6) Έστω οι περιοχές Α και Β από την προηγούμενη άσκηση: Υπολογίστε το εμβαδόν των δύο περιοχών (Α και Β) ΧΩΡΙΣ όμως να περιλαμβάνεται η επικαλυπτόμενη περιοχή δηλαδή η τομή τους.

# %%
# code

# %% [markdown]
# # Απαραίτητες οδηγίες για την επίλυση και υποβολή των ασκήσεων
# Κάτω απο κάθε εκφώνηση βρίσκεται ένα πεδίο (cell) (# your code here...) που θα γράψετε τον κώδικα σας ώστε να επιλυθεί η άσκηση. Για να εκτελεστεί ο κώδικας σε κάθε cell θα πρέπει να επιλέγετε shift-enter. Τα αποτελέσματα ή τα σφάλματα που θα εξάγονται, θα εμφανίζονται ακριβώς από κάτω. <br>
#
# Πριν την υποβολή επιλέξτε με το ποντίκι το όνομα του αρχείου: Exercises_Python_all_final που βρίσκεται πάνω αριστερά της οθόνης και μετονομάστε το σε: Ex_python_epitheto_onoma
#
# Επίσης στο κενό cell που υπάρχει κάτω από το "Ονομα / Επίθετο", πληκτρολογείστε το όνομα και το επίθετο σας. Στη συνέχεια επιλέξτε shift-enter.
#
# Η υποβολή της άσκησης θα γίνεται αποδεκτή ΜΟΝΟ μέσω του e-class. Κατά την υποβολή της σειράς ασκήσεων Python θα παραδώσετε ΜΟΝΟ το αρχείο .ipynb που περιέχει τις εκφωνήσεις με συμπληρωμένο τον κώδικα που γράψατε για κάθε άσκηση.
